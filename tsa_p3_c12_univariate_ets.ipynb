# %%
# 01_grid_search.py
# grid search holt winter's exponential smoothing
from math import sqrt
from multiprocessing import cpu_count
from joblib import Parallel
from joblib import delayed
from warnings import catch_warnings
from warnings import filterwarnings
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
from numpy import array

# one-step Holt Winter’s Exponential Smoothing forecast
def exp_smoothing_forecast(history, config):
	t,d,s,p,b,r = config
	# define model
	history = array(history)
	model = ExponentialSmoothing(history, trend=t, damped=d, seasonal=s, seasonal_periods=p)
	# fit model
	model_fit = model.fit(optimized=True, use_boxcox=b, remove_bias=r)
	# make one step forecast
	yhat = model_fit.predict(len(history), len(history))
	return yhat[0]

# root mean squared error or rmse
def measure_rmse(actual, predicted):
	return sqrt(mean_squared_error(actual, predicted))

# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
	return data[:-n_test], data[-n_test:]

# walk-forward validation for univariate data
def walk_forward_validation(data, n_test, cfg):
	predictions = list()
	# split dataset
	train, test = train_test_split(data, n_test)
	# seed history with training dataset
	history = [x for x in train]
	# step over each time-step in the test set
	for i in range(len(test)):
		# fit model and make forecast for history
		yhat = exp_smoothing_forecast(history, cfg)
		# store forecast in list of predictions
		predictions.append(yhat)
		# add actual observation to history for the next loop
		history.append(test[i])
	# estimate prediction error
	error = measure_rmse(test, predictions)
	return error

# score a model, return None on failure
def score_model(data, n_test, cfg, debug=False):
	result = None
	# convert config to a key
	key = str(cfg)
	# show all warnings and fail on exception if debugging
	if debug:
		result = walk_forward_validation(data, n_test, cfg)
	else:
		# one failure during model validation suggests an unstable config
		try:
			# never show warnings when grid searching, too noisy
			with catch_warnings():
				filterwarnings("ignore")
				result = walk_forward_validation(data, n_test, cfg)
		except:
			error = None
	# check for an interesting result
	if result is not None:
		print(' > Model[%s] %.3f' % (key, result))
	return (key, result)

# grid search configs
def grid_search(data, cfg_list, n_test, parallel=True):
	scores = None
	if parallel:
		# execute configs in parallel
		executor = Parallel(n_jobs=cpu_count(), backend='multiprocessing')
		tasks = (delayed(score_model)(data, n_test, cfg) for cfg in cfg_list)
		scores = executor(tasks)
	else:
		scores = [score_model(data, n_test, cfg) for cfg in cfg_list]
	# remove empty results
	scores = [r for r in scores if r[1] != None]
	# sort configs by error, asc
	scores.sort(key=lambda tup: tup[1])
	return scores

# create a set of exponential smoothing configs to try
def exp_smoothing_configs(seasonal=[None]):
	models = list()
	# define config lists
	t_params = ['add', 'mul', None]
	d_params = [True, False]
	s_params = ['add', 'mul', None]
	p_params = seasonal
	b_params = [True, False]
	r_params = [True, False]
	# create config instances
	for t in t_params:
		for d in d_params:
			for s in s_params:
				for p in p_params:
					for b in b_params:
						for r in r_params:
							cfg = [t,d,s,p,b,r]
							models.append(cfg)
	return models

__name__ == '__main__'
if __name__ == '__main__':
	# define dataset
	data = [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0]
	print(data)
	# data split
	n_test = 4
	# model configs
	cfg_list = exp_smoothing_configs()
	# grid search
	scores = grid_search(data, cfg_list, n_test)
	print('done')
	# list top 3 configs
	for cfg, error in scores[:3]:
		print(cfg, error)
# Out:
# [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0]
#  > Model[['add', True, None, None, False, True]] 0.115
#  > Model[['add', True, None, None, True, True]] 0.953
#  > Model[['add', True, None, None, False, False]] 0.121
#  > Model[['add', True, None, None, True, False]] 0.964
#  > Model[['add', False, None, None, True, True]] 2.416
#  > Model[['mul', True, None, None, True, True]] 1.755
#  > Model[['add', False, None, None, True, False]] 2.415
#  > Model[['mul', True, None, None, True, False]] 0.808
#  > Model[['add', False, None, None, False, True]] 0.000
#  > Model[['mul', True, None, None, False, True]] 1.612
#  > Model[['add', False, None, None, False, False]] 0.000
#  > Model[['mul', True, None, None, False, False]] 0.900
#  > Model[['mul', False, None, None, True, True]] 1.941
#  > Model[[None, False, None, None, True, True]] 1.380
#  > Model[[None, False, None, None, True, False]] 10.000
#  > Model[[None, False, None, None, False, True]] 2.563
#  > Model[['mul', False, None, None, True, False]] 1.680
#  > Model[[None, False, None, None, False, False]] 10.000
#  > Model[['mul', False, None, None, False, True]] 1.584
#  > Model[['mul', False, None, None, False, False]] 1.611
# done
# ['add', False, None, None, False, False] 6.96168838095118e-06
# ['add', False, None, None, False, True] 3.207020977639108e-05
# ['add', True, None, None, False, True] 0.11515367072043833

# %%
# 02_grid_search_daily_births.py
# grid search ets models for daily female births
from math import sqrt
from multiprocessing import cpu_count
from joblib import Parallel
from joblib import delayed
from warnings import catch_warnings
from warnings import filterwarnings
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
from pandas import read_csv
from numpy import array

# one-step Holt Winter’s Exponential Smoothing forecast
def exp_smoothing_forecast(history, config):
	t,d,s,p,b,r = config
	# define model
	history = array(history)
	model = ExponentialSmoothing(history, trend=t, damped=d, seasonal=s, seasonal_periods=p)
	# fit model
	model_fit = model.fit(optimized=True, use_boxcox=b, remove_bias=r)
	# make one step forecast
	yhat = model_fit.predict(len(history), len(history))
	return yhat[0]

# root mean squared error or rmse
def measure_rmse(actual, predicted):
	return sqrt(mean_squared_error(actual, predicted))

# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
	return data[:-n_test], data[-n_test:]

# walk-forward validation for univariate data
def walk_forward_validation(data, n_test, cfg):
	predictions = list()
	# split dataset
	train, test = train_test_split(data, n_test)
	# seed history with training dataset
	history = [x for x in train]
	# step over each time-step in the test set
	for i in range(len(test)):
		# fit model and make forecast for history
		yhat = exp_smoothing_forecast(history, cfg)
		# store forecast in list of predictions
		predictions.append(yhat)
		# add actual observation to history for the next loop
		history.append(test[i])
	# estimate prediction error
	error = measure_rmse(test, predictions)
	return error

# score a model, return None on failure
def score_model(data, n_test, cfg, debug=False):
	result = None
	# convert config to a key
	key = str(cfg)
	# show all warnings and fail on exception if debugging
	if debug:
		result = walk_forward_validation(data, n_test, cfg)
	else:
		# one failure during model validation suggests an unstable config
		try:
			# never show warnings when grid searching, too noisy
			with catch_warnings():
				filterwarnings("ignore")
				result = walk_forward_validation(data, n_test, cfg)
		except:
			error = None
	# check for an interesting result
	if result is not None:
		print(' > Model[%s] %.3f' % (key, result))
	return (key, result)

# grid search configs
def grid_search(data, cfg_list, n_test, parallel=True):
	scores = None
	if parallel:
		# execute configs in parallel
		executor = Parallel(n_jobs=cpu_count(), backend='multiprocessing')
		tasks = (delayed(score_model)(data, n_test, cfg) for cfg in cfg_list)
		scores = executor(tasks)
	else:
		scores = [score_model(data, n_test, cfg) for cfg in cfg_list]
	# remove empty results
	scores = [r for r in scores if r[1] != None]
	# sort configs by error, asc
	scores.sort(key=lambda tup: tup[1])
	return scores

# create a set of exponential smoothing configs to try
def exp_smoothing_configs(seasonal=[None]):
	models = list()
	# define config lists
	t_params = ['add', 'mul', None]
	d_params = [True, False]
	s_params = ['add', 'mul', None]
	p_params = seasonal
	b_params = [True, False]
	r_params = [True, False]
	# create config instances
	for t in t_params:
		for d in d_params:
			for s in s_params:
				for p in p_params:
					for b in b_params:
						for r in r_params:
							cfg = [t,d,s,p,b,r]
							models.append(cfg)
	return models

if __name__ == '__main__':
	# load dataset
	series = read_csv('daily-total-female-births.csv', header=0, index_col=0)
	data = series.values
	# data split
	n_test = 165
	# model configs
	cfg_list = exp_smoothing_configs()
	# grid search
	scores = grid_search(data[:,0], cfg_list, n_test)
	print('done')
	# list top 3 configs
	for cfg, error in scores[:3]:
		print(cfg, error)
# Out:
#  > Model[['add', True, None, None, False, True]] 7.248
#  > Model[['add', True, None, None, True, True]] 7.321
#  > Model[['add', True, None, None, False, False]] 7.239
#  > Model[['add', True, None, None, True, False]] 7.364
#  > Model[['add', False, None, None, True, True]] 7.162
#  > Model[['add', False, None, None, True, False]] 7.169
#  > Model[['add', False, None, None, False, True]] 7.163
#  > Model[['mul', True, None, None, True, True]] 20.493
#  > Model[['add', False, None, None, False, False]] 7.153
#  > Model[['mul', True, None, None, True, False]] 452.670
#  > Model[['mul', True, None, None, False, True]] 7.999
#  > Model[['mul', False, None, None, True, True]] 7.132
#  > Model[['mul', False, None, None, True, False]] 7.137
#  > Model[['mul', True, None, None, False, False]] 26.588
#  > Model[['mul', False, None, None, False, True]] 7.193
#  > Model[[None, False, None, None, True, True]] 7.123
#  > Model[['mul', False, None, None, False, False]] 7.184
#  > Model[[None, False, None, None, True, False]] 7.175
#  > Model[[None, False, None, None, False, True]] 7.121
#  > Model[[None, False, None, None, False, False]] 7.130
# done
# [None, False, None, None, False, True] 7.120813209471283
# [None, False, None, None, True, True] 7.123337557742778
# [None, False, None, None, False, False] 7.1299539248543375

# %%
# 03_grid_search_monthly_shampoo_sales.py
# grid search ets models for monthly shampoo sales
from math import sqrt
from multiprocessing import cpu_count
from joblib import Parallel
from joblib import delayed
from warnings import catch_warnings
from warnings import filterwarnings
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
from pandas import read_csv
from numpy import array

# one-step Holt Winter’s Exponential Smoothing forecast
def exp_smoothing_forecast(history, config):
	t,d,s,p,b,r = config
	# define model
	history = array(history)
	model = ExponentialSmoothing(history, trend=t, damped=d, seasonal=s, seasonal_periods=p)
	# fit model
	model_fit = model.fit(optimized=True, use_boxcox=b, remove_bias=r)
	# make one step forecast
	yhat = model_fit.predict(len(history), len(history))
	return yhat[0]

# root mean squared error or rmse
def measure_rmse(actual, predicted):
	return sqrt(mean_squared_error(actual, predicted))

# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
	return data[:-n_test], data[-n_test:]

# walk-forward validation for univariate data
def walk_forward_validation(data, n_test, cfg):
	predictions = list()
	# split dataset
	train, test = train_test_split(data, n_test)
	# seed history with training dataset
	history = [x for x in train]
	# step over each time-step in the test set
	for i in range(len(test)):
		# fit model and make forecast for history
		yhat = exp_smoothing_forecast(history, cfg)
		# store forecast in list of predictions
		predictions.append(yhat)
		# add actual observation to history for the next loop
		history.append(test[i])
	# estimate prediction error
	error = measure_rmse(test, predictions)
	return error

# score a model, return None on failure
def score_model(data, n_test, cfg, debug=False):
	result = None
	# convert config to a key
	key = str(cfg)
	# show all warnings and fail on exception if debugging
	if debug:
		result = walk_forward_validation(data, n_test, cfg)
	else:
		# one failure during model validation suggests an unstable config
		try:
			# never show warnings when grid searching, too noisy
			with catch_warnings():
				filterwarnings("ignore")
				result = walk_forward_validation(data, n_test, cfg)
		except:
			error = None
	# check for an interesting result
	if result is not None:
		print(' > Model[%s] %.3f' % (key, result))
	return (key, result)

# grid search configs
def grid_search(data, cfg_list, n_test, parallel=True):
	scores = None
	if parallel:
		# execute configs in parallel
		executor = Parallel(n_jobs=cpu_count(), backend='multiprocessing')
		tasks = (delayed(score_model)(data, n_test, cfg) for cfg in cfg_list)
		scores = executor(tasks)
	else:
		scores = [score_model(data, n_test, cfg) for cfg in cfg_list]
	# remove empty results
	scores = [r for r in scores if r[1] != None]
	# sort configs by error, asc
	scores.sort(key=lambda tup: tup[1])
	return scores

# create a set of exponential smoothing configs to try
def exp_smoothing_configs(seasonal=[None]):
	models = list()
	# define config lists
	t_params = ['add', 'mul', None]
	d_params = [True, False]
	s_params = ['add', 'mul', None]
	p_params = seasonal
	b_params = [True, False]
	r_params = [True, False]
	# create config instances
	for t in t_params:
		for d in d_params:
			for s in s_params:
				for p in p_params:
					for b in b_params:
						for r in r_params:
							cfg = [t,d,s,p,b,r]
							models.append(cfg)
	return models

if __name__ == '__main__':
	# load dataset
	series = read_csv('monthly-shampoo-sales.csv', header=0, index_col=0)
	data = series.values
	# data split
	n_test = 12
	# model configs
	cfg_list = exp_smoothing_configs()
	# grid search
	scores = grid_search(data[:,0], cfg_list, n_test)
	print('done')
	# list top 3 configs
	for cfg, error in scores[:3]:
		print(cfg, error)
# Out:
#  > Model[['add', True, None, None, False, True]] 100.234
#  > Model[['add', True, None, None, True, True]] 86.905
#  > Model[['add', True, None, None, False, False]] 100.319
#  > Model[['add', True, None, None, True, False]] 89.965
#  > Model[['add', False, None, None, True, True]] 100.061
#  > Model[['add', False, None, None, True, False]] 102.000
#  > Model[['mul', True, None, None, True, True]] 280.265
#  > Model[['add', False, None, None, False, True]] 90.291
#  > Model[['add', False, None, None, False, False]] 90.624
#  > Model[['mul', True, None, None, True, False]] 395.583
#  > Model[['mul', False, None, None, True, True]] 94.004
#  > Model[['mul', True, None, None, False, True]] 88.444
#  > Model[['mul', False, None, None, True, False]] 95.774
#  > Model[['mul', True, None, None, False, False]] 88.487
#  > Model[[None, False, None, None, True, True]] 96.687
#  > Model[['mul', False, None, None, False, True]] 99.128
#  > Model[[None, False, None, None, True, False]] 112.383
#  > Model[[None, False, None, None, False, True]] 99.416
#  > Model[[None, False, None, None, False, False]] 108.031
#  > Model[['mul', False, None, None, False, False]] 96.888
# done
# ['add', True, None, None, True, True] 86.90532709009291
# ['mul', True, None, None, False, True] 88.4439016904098
# ['mul', True, None, None, False, False] 88.48727907334467

# %%
# 04_grid_search_monthly_mean_temp.py
# grid search ets hyperparameters for monthly mean temp dataset
from math import sqrt
from multiprocessing import cpu_count
from joblib import Parallel
from joblib import delayed
from warnings import catch_warnings
from warnings import filterwarnings
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
from pandas import read_csv
from numpy import array

# one-step Holt Winter’s Exponential Smoothing forecast
def exp_smoothing_forecast(history, config):
	t,d,s,p,b,r = config
	# define model
	history = array(history)
	model = ExponentialSmoothing(history, trend=t, damped=d, seasonal=s, seasonal_periods=p)
	# fit model
	model_fit = model.fit(optimized=True, use_boxcox=b, remove_bias=r)
	# make one step forecast
	yhat = model_fit.predict(len(history), len(history))
	return yhat[0]

# root mean squared error or rmse
def measure_rmse(actual, predicted):
	return sqrt(mean_squared_error(actual, predicted))

# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
	return data[:-n_test], data[-n_test:]

# walk-forward validation for univariate data
def walk_forward_validation(data, n_test, cfg):
	predictions = list()
	# split dataset
	train, test = train_test_split(data, n_test)
	# seed history with training dataset
	history = [x for x in train]
	# step over each time-step in the test set
	for i in range(len(test)):
		# fit model and make forecast for history
		yhat = exp_smoothing_forecast(history, cfg)
		# store forecast in list of predictions
		predictions.append(yhat)
		# add actual observation to history for the next loop
		history.append(test[i])
	# estimate prediction error
	error = measure_rmse(test, predictions)
	return error

# score a model, return None on failure
def score_model(data, n_test, cfg, debug=False):
	result = None
	# convert config to a key
	key = str(cfg)
	# show all warnings and fail on exception if debugging
	if debug:
		result = walk_forward_validation(data, n_test, cfg)
	else:
		# one failure during model validation suggests an unstable config
		try:
			# never show warnings when grid searching, too noisy
			with catch_warnings():
				filterwarnings("ignore")
				result = walk_forward_validation(data, n_test, cfg)
		except:
			error = None
	# check for an interesting result
	if result is not None:
		print(' > Model[%s] %.3f' % (key, result))
	return (key, result)

# grid search configs
def grid_search(data, cfg_list, n_test, parallel=True):
	scores = None
	if parallel:
		# execute configs in parallel
		executor = Parallel(n_jobs=cpu_count(), backend='multiprocessing')
		tasks = (delayed(score_model)(data, n_test, cfg) for cfg in cfg_list)
		scores = executor(tasks)
	else:
		scores = [score_model(data, n_test, cfg) for cfg in cfg_list]
	# remove empty results
	scores = [r for r in scores if r[1] != None]
	# sort configs by error, asc
	scores.sort(key=lambda tup: tup[1])
	return scores

# create a set of exponential smoothing configs to try
def exp_smoothing_configs(seasonal=[None]):
	models = list()
	# define config lists
	t_params = ['add', 'mul', None]
	d_params = [True, False]
	s_params = ['add', 'mul', None]
	p_params = seasonal
	b_params = [True, False]
	r_params = [True, False]
	# create config instances
	for t in t_params:
		for d in d_params:
			for s in s_params:
				for p in p_params:
					for b in b_params:
						for r in r_params:
							cfg = [t,d,s,p,b,r]
							models.append(cfg)
	return models

if __name__ == '__main__':
	# load dataset
	series = read_csv('monthly-mean-temp.csv', header=0, index_col=0)
	data = series.values
	# trim dataset to 5 years
	data = data[-(5*12):]
	# data split
	n_test = 12
	# model configs
	cfg_list = exp_smoothing_configs(seasonal=[0,12])
	# grid search
	scores = grid_search(data[:,0], cfg_list, n_test)
	print('done')
	# list top 3 configs
	for cfg, error in scores[:3]:
		print(cfg, error)
# Out:
#  > Model[['add', True, 'add', 12, True, True]] 1.505
#  > Model[['add', True, 'add', 12, False, True]] 1.508
#  > Model[['add', True, 'add', 12, False, False]] 1.508
#  > Model[['add', True, 'add', 12, True, False]] 1.508
#  > Model[['add', True, 'mul', 12, True, True]] 1.515
#  > Model[['add', True, 'mul', 12, True, False]] 1.520
#  > Model[['add', True, 'mul', 12, False, True]] 1.505
#  > Model[['add', True, 'mul', 12, False, False]] 1.505
#  > Model[['add', True, None, 0, True, True]] 4.677
#  > Model[['add', True, None, 0, True, False]] 4.602
#  > Model[['add', True, None, 0, False, True]] 4.824
#  > Model[['add', True, None, 0, False, False]] 4.776
#  > Model[['add', True, None, 12, True, True]] 4.677
#  > Model[['add', True, None, 12, True, False]] 4.602
#  > Model[['add', True, None, 12, False, True]] 4.824
#  > Model[['add', True, None, 12, False, False]] 4.776
#  > Model[['add', False, 'add', 12, True, True]] 1.647
#  > Model[['add', False, 'add', 12, True, False]] 1.637
#  > Model[['add', False, 'add', 12, False, True]] 1.579
#  > Model[['add', False, 'add', 12, False, False]] 1.579
#  > Model[['add', False, 'mul', 12, True, True]] 1.628
#  > Model[['add', False, 'mul', 12, True, False]] 1.619
#  > Model[['add', False, 'mul', 12, False, True]] 1.547
#  > Model[['add', False, 'mul', 12, False, False]] 1.547
#  > Model[['add', False, None, 0, True, True]] 4.967
#  > Model[['add', False, None, 0, True, False]] 4.894
#  > Model[['add', False, None, 0, False, True]] 5.197
#  > Model[['add', False, None, 0, False, False]] 5.143
#  > Model[['add', False, None, 12, True, True]] 4.967
#  > Model[['add', False, None, 12, True, False]] 4.894
#  > Model[['add', False, None, 12, False, True]] 5.197
#  > Model[['add', False, None, 12, False, False]] 5.143
#  > Model[['mul', True, 'add', 12, True, True]] 203.505
#  > Model[['mul', True, 'add', 12, True, False]] 270.985
#  > Model[['mul', True, 'add', 12, False, True]] 5.879
#  > Model[['mul', True, 'add', 12, False, False]] 11.357
#  > Model[['mul', True, 'mul', 12, False, True]] 14.152
#  > Model[['mul', True, 'mul', 12, False, False]] 73.079
#  > Model[['mul', True, None, 0, True, True]] 5.125
#  > Model[['mul', True, None, 0, True, False]] 4.554
#  > Model[['mul', True, None, 0, False, True]] 4.621
#  > Model[['mul', True, None, 0, False, False]] 4.576
#  > Model[['mul', True, None, 12, True, True]] 5.125
#  > Model[['mul', True, None, 12, True, False]] 4.554
#  > Model[['mul', True, None, 12, False, True]] 4.621
#  > Model[['mul', True, None, 12, False, False]] 4.576
#  > Model[['mul', False, 'add', 12, True, True]] 1.642
#  > Model[['mul', False, 'add', 12, True, False]] 1.632
#  > Model[['mul', False, 'add', 12, False, True]] 1.580
#  > Model[['mul', False, 'add', 12, False, False]] 1.580
#  > Model[['mul', False, 'mul', 12, True, True]] 1.630
#  > Model[['mul', False, 'mul', 12, True, False]] 1.620
#  > Model[['mul', False, 'mul', 12, False, True]] 1.548
#  > Model[['mul', False, 'mul', 12, False, False]] 1.548
#  > Model[['mul', False, None, 0, True, True]] 4.855
#  > Model[['mul', False, None, 0, True, False]] 4.817
#  > Model[['mul', False, None, 0, False, True]] 4.858
#  > Model[['mul', False, None, 0, False, False]] 4.830
#  > Model[['mul', False, None, 12, True, True]] 4.855
#  > Model[['mul', False, None, 12, True, False]] 4.817
#  > Model[['mul', False, None, 12, False, True]] 4.858
#  > Model[['mul', False, None, 12, False, False]] 4.830
#  > Model[[None, False, 'add', 12, True, True]] 1.507
#  > Model[[None, False, 'mul', 12, True, True]] 1.507
#  > Model[[None, False, 'add', 12, True, False]] 1.507
#  > Model[[None, False, 'mul', 12, True, False]] 1.506
#  > Model[[None, False, 'add', 12, False, True]] 1.502
#  > Model[[None, False, 'add', 12, False, False]] 1.502
#  > Model[[None, False, 'mul', 12, False, True]] 1.502
#  > Model[[None, False, None, 0, True, True]] 5.188
#  > Model[[None, False, None, 0, True, False]] 5.143
#  > Model[[None, False, None, 0, False, True]] 5.187
#  > Model[[None, False, None, 0, False, False]] 5.143
#  > Model[[None, False, 'mul', 12, False, False]] 1.502
#  > Model[[None, False, None, 12, True, True]] 5.188
#  > Model[[None, False, None, 12, True, False]] 5.143
#  > Model[[None, False, None, 12, False, True]] 5.187
#  > Model[[None, False, None, 12, False, False]] 5.143
# done
# [None, False, 'add', 12, False, False] 1.5015521597703008
# [None, False, 'add', 12, False, True] 1.5015554955632213
# [None, False, 'mul', 12, False, True] 1.501559274317846

# %%
# 05_grid_search_monthly_car_sales.py
# grid search ets models for monthly car sales
from math import sqrt
from multiprocessing import cpu_count
from joblib import Parallel
from joblib import delayed
from warnings import catch_warnings
from warnings import filterwarnings
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
from pandas import read_csv
from numpy import array

# one-step Holt Winter’s Exponential Smoothing forecast
def exp_smoothing_forecast(history, config):
	t,d,s,p,b,r = config
	# define model
	history = array(history)
	model = ExponentialSmoothing(history, trend=t, damped=d, seasonal=s, seasonal_periods=p)
	# fit model
	model_fit = model.fit(optimized=True, use_boxcox=b, remove_bias=r)
	# make one step forecast
	yhat = model_fit.predict(len(history), len(history))
	return yhat[0]

# root mean squared error or rmse
def measure_rmse(actual, predicted):
	return sqrt(mean_squared_error(actual, predicted))

# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
	return data[:-n_test], data[-n_test:]

# walk-forward validation for univariate data
def walk_forward_validation(data, n_test, cfg):
	predictions = list()
	# split dataset
	train, test = train_test_split(data, n_test)
	# seed history with training dataset
	history = [x for x in train]
	# step over each time-step in the test set
	for i in range(len(test)):
		# fit model and make forecast for history
		yhat = exp_smoothing_forecast(history, cfg)
		# store forecast in list of predictions
		predictions.append(yhat)
		# add actual observation to history for the next loop
		history.append(test[i])
	# estimate prediction error
	error = measure_rmse(test, predictions)
	return error

# score a model, return None on failure
def score_model(data, n_test, cfg, debug=False):
	result = None
	# convert config to a key
	key = str(cfg)
	# show all warnings and fail on exception if debugging
	if debug:
		result = walk_forward_validation(data, n_test, cfg)
	else:
		# one failure during model validation suggests an unstable config
		try:
			# never show warnings when grid searching, too noisy
			with catch_warnings():
				filterwarnings("ignore")
				result = walk_forward_validation(data, n_test, cfg)
		except:
			error = None
	# check for an interesting result
	if result is not None:
		print(' > Model[%s] %.3f' % (key, result))
	return (key, result)

# grid search configs
def grid_search(data, cfg_list, n_test, parallel=True):
	scores = None
	if parallel:
		# execute configs in parallel
		executor = Parallel(n_jobs=cpu_count(), backend='multiprocessing')
		tasks = (delayed(score_model)(data, n_test, cfg) for cfg in cfg_list)
		scores = executor(tasks)
	else:
		scores = [score_model(data, n_test, cfg) for cfg in cfg_list]
	# remove empty results
	scores = [r for r in scores if r[1] != None]
	# sort configs by error, asc
	scores.sort(key=lambda tup: tup[1])
	return scores

# create a set of exponential smoothing configs to try
def exp_smoothing_configs(seasonal=[None]):
	models = list()
	# define config lists
	t_params = ['add', 'mul', None]
	d_params = [True, False]
	s_params = ['add', 'mul', None]
	p_params = seasonal
	b_params = [True, False]
	r_params = [True, False]
	# create config instances
	for t in t_params:
		for d in d_params:
			for s in s_params:
				for p in p_params:
					for b in b_params:
						for r in r_params:
							cfg = [t,d,s,p,b,r]
							models.append(cfg)
	return models

if __name__ == '__main__':
	# load dataset
	series = read_csv('monthly-car-sales.csv', header=0, index_col=0)
	data = series.values
	# data split
	n_test = 12
	# model configs
	cfg_list = exp_smoothing_configs(seasonal=[0,6,12])
	# grid search
	scores = grid_search(data[:,0], cfg_list, n_test)
	print('done')
	# list top 3 configs
	for cfg, error in scores[:3]:
		print(cfg, error)
# Out:
#  > Model[['add', True, 'add', 6, False, True]] 3232.412
#  > Model[['add', True, 'add', 6, True, True]] 2930.314
#  > Model[['add', True, 'add', 6, False, False]] 3202.886
#  > Model[['add', True, 'add', 6, True, False]] 2916.004
#  > Model[['add', True, 'add', 12, True, True]] 1944.900
#  > Model[['add', True, 'add', 12, False, True]] 1659.754
#  > Model[['add', True, 'add', 12, False, False]] 1724.250
#  > Model[['add', True, 'add', 12, True, False]] 1947.757
#  > Model[['add', True, 'mul', 6, True, True]] 2971.065
#  > Model[['add', True, 'mul', 6, True, False]] 2970.927
#  > Model[['add', True, 'mul', 6, False, True]] 3067.653
#  > Model[['add', True, 'mul', 6, False, False]] 3071.061
#  > Model[['add', True, 'mul', 12, True, True]] 2033.101
#  > Model[['add', True, 'mul', 12, True, False]] 2033.559
#  > Model[['add', True, 'mul', 12, False, True]] 1840.965
#  > Model[['add', True, 'mul', 12, False, False]] 1844.222
#  > Model[['add', True, None, 0, True, True]] 3802.513
#  > Model[['add', True, None, 0, True, False]] 3783.966
#  > Model[['add', True, None, 0, False, True]] 3878.934
#  > Model[['add', True, None, 0, False, False]] 3870.186
#  > Model[['add', True, None, 6, True, True]] 3802.513
#  > Model[['add', True, None, 6, True, False]] 3783.966
#  > Model[['add', True, None, 6, False, True]] 3878.934
#  > Model[['add', True, None, 6, False, False]] 3870.186
#  > Model[['add', True, None, 12, True, True]] 3802.513
#  > Model[['add', True, None, 12, True, False]] 3783.966
#  > Model[['add', True, None, 12, False, True]] 3878.934
#  > Model[['add', True, None, 12, False, False]] 3870.186
#  > Model[['add', False, 'add', 6, True, True]] 2970.409
#  > Model[['add', False, 'add', 6, True, False]] 2969.597
#  > Model[['add', False, 'add', 6, False, True]] 3252.696
#  > Model[['add', False, 'add', 6, False, False]] 3236.850
#  > Model[['add', False, 'add', 12, True, True]] 1833.387
#  > Model[['add', False, 'add', 12, True, False]] 1833.505
#  > Model[['add', False, 'add', 12, False, True]] 1626.294
#  > Model[['add', False, 'add', 12, False, False]] 1610.906
#  > Model[['add', False, 'mul', 6, True, True]] 2982.712
#  > Model[['add', False, 'mul', 6, True, False]] 2980.251
#  > Model[['add', False, 'mul', 6, False, True]] 3107.064
#  > Model[['add', False, 'mul', 6, False, False]] 3089.899
#  > Model[['add', False, 'mul', 12, True, True]] 1982.207
#  > Model[['add', False, 'mul', 12, True, False]] 1981.249
#  > Model[['add', False, 'mul', 12, False, True]] 1837.225
#  > Model[['add', False, 'mul', 12, False, False]] 1833.694
#  > Model[['add', False, None, 0, True, True]] 3814.551
#  > Model[['add', False, None, 0, True, False]] 3811.726
#  > Model[['add', False, None, 0, False, True]] 3914.757
#  > Model[['add', False, None, 0, False, False]] 3869.388
#  > Model[['add', False, None, 6, True, True]] 3814.551
#  > Model[['add', False, None, 6, True, False]] 3811.726
#  > Model[['add', False, None, 6, False, True]] 3914.757
#  > Model[['add', False, None, 6, False, False]] 3869.388
#  > Model[['add', False, None, 12, True, True]] 3814.551
#  > Model[['add', False, None, 12, True, False]] 3811.726
#  > Model[['add', False, None, 12, False, True]] 3914.757
#  > Model[['add', False, None, 12, False, False]] 3869.388
#  > Model[['mul', True, 'add', 6, True, True]] 3023.545
#  > Model[['mul', True, 'add', 6, True, False]] 2976.132
#  > Model[['mul', True, 'add', 6, False, True]] 3181.164
#  > Model[['mul', True, 'add', 6, False, False]] 3280.625
#  > Model[['mul', True, 'add', 12, True, True]] 56558.584
#  > Model[['mul', True, 'add', 12, True, False]] 98399.229
#  > Model[['mul', True, 'add', 12, False, True]] 2912.345
#  > Model[['mul', True, 'add', 12, False, False]] 4181.130
#  > Model[['mul', True, 'mul', 6, True, True]] 2984.072
#  > Model[['mul', True, 'mul', 6, True, False]] 2952.538
#  > Model[['mul', True, 'mul', 6, False, True]] 3079.042
#  > Model[['mul', True, 'mul', 6, False, False]] 3088.735
#  > Model[['mul', True, 'mul', 12, True, False]] 44230.388
#  > Model[['mul', True, 'mul', 12, True, True]] 29096.905
#  > Model[['mul', True, 'mul', 12, False, True]] 1867.115
#  > Model[['mul', True, 'mul', 12, False, False]] 1829.610
#  > Model[['mul', True, None, 0, True, True]] 3811.394
#  > Model[['mul', True, None, 0, True, False]] 3783.911
#  > Model[['mul', True, None, 0, False, True]] 3972.279
#  > Model[['mul', True, None, 0, False, False]] 3978.356
#  > Model[['mul', True, None, 6, True, True]] 3811.394
#  > Model[['mul', True, None, 6, True, False]] 3783.911
#  > Model[['mul', True, None, 6, False, True]] 3972.279
#  > Model[['mul', True, None, 6, False, False]] 3978.356
#  > Model[['mul', True, None, 12, True, True]] 3811.394
#  > Model[['mul', True, None, 12, True, False]] 3783.911
#  > Model[['mul', True, None, 12, False, True]] 3972.279
#  > Model[['mul', True, None, 12, False, False]] 3978.356
#  > Model[['mul', False, 'add', 6, True, True]] 2974.208
#  > Model[['mul', False, 'add', 6, True, False]] 2974.381
#  > Model[['mul', False, 'add', 6, False, True]] 3226.962
#  > Model[['mul', False, 'add', 6, False, False]] 3282.096
#  > Model[['mul', False, 'add', 12, True, True]] 1850.510
#  > Model[['mul', False, 'add', 12, True, False]] 1848.995
#  > Model[['mul', False, 'add', 12, False, True]] 1599.194
#  > Model[['mul', False, 'add', 12, False, False]] 1544.132
#  > Model[['mul', False, 'mul', 6, True, True]] 2981.702
#  > Model[['mul', False, 'mul', 6, True, False]] 2976.071
#  > Model[['mul', False, 'mul', 6, False, True]] 3275.669
#  > Model[['mul', False, 'mul', 6, False, False]] 3452.514
#  > Model[['mul', False, 'mul', 12, True, True]] 1983.363
#  > Model[['mul', False, 'mul', 12, True, False]] 1982.915
#  > Model[['mul', False, 'mul', 12, False, True]] 1838.946
#  > Model[['mul', False, 'mul', 12, False, False]] 1827.039
#  > Model[['mul', False, None, 0, True, True]] 3804.871
#  > Model[['mul', False, None, 0, True, False]] 3805.297
#  > Model[['mul', False, None, 0, False, True]] 4052.878
#  > Model[['mul', False, None, 0, False, False]] 4070.491
#  > Model[['mul', False, None, 6, True, True]] 3804.871
#  > Model[['mul', False, None, 6, True, False]] 3805.297
#  > Model[['mul', False, None, 6, False, True]] 4052.878
#  > Model[['mul', False, None, 6, False, False]] 4070.491
#  > Model[['mul', False, None, 12, True, True]] 3804.871
#  > Model[['mul', False, None, 12, True, False]] 3805.297
#  > Model[['mul', False, None, 12, False, True]] 4052.878
#  > Model[['mul', False, None, 12, False, False]] 4070.491
#  > Model[[None, False, 'add', 6, True, True]] 2938.516
#  > Model[[None, False, 'add', 6, False, True]] 3155.946
#  > Model[[None, False, 'add', 6, False, False]] 3140.845
#  > Model[[None, False, 'add', 6, True, False]] 2925.266
#  > Model[[None, False, 'add', 12, True, True]] 1835.016
#  > Model[[None, False, 'mul', 6, True, True]] 2974.518
#  > Model[[None, False, 'add', 12, True, False]] 1872.212
#  > Model[[None, False, 'mul', 6, True, False]] 2958.054
#  > Model[[None, False, 'add', 12, False, True]] 1721.966
#  > Model[[None, False, 'mul', 6, False, True]] 3078.688
#  > Model[[None, False, 'add', 12, False, False]] 1776.541
#  > Model[[None, False, 'mul', 6, False, False]] 3059.899
#  > Model[[None, False, 'mul', 12, False, True]] 1805.985
#  > Model[[None, False, 'mul', 12, False, False]] 1824.994
#  > Model[[None, False, None, 0, True, True]] 3801.741
#  > Model[[None, False, 'mul', 12, True, True]] 1972.542
#  > Model[[None, False, None, 0, True, False]] 3783.966
#  > Model[[None, False, None, 0, False, True]] 3800.397
#  > Model[[None, False, None, 0, False, False]] 3782.817
#  > Model[[None, False, None, 6, True, True]] 3801.741
#  > Model[[None, False, None, 6, True, False]] 3783.966
#  > Model[[None, False, None, 6, False, True]] 3800.397
#  > Model[[None, False, 'mul', 12, True, False]] 1989.230
#  > Model[[None, False, None, 6, False, False]] 3782.817
#  > Model[[None, False, None, 12, True, True]] 3801.741
#  > Model[[None, False, None, 12, True, False]] 3783.966
#  > Model[[None, False, None, 12, False, True]] 3800.397
#  > Model[[None, False, None, 12, False, False]] 3782.817
# done
# ['mul', False, 'add', 12, False, False] 1544.131872491465
# ['mul', False, 'add', 12, False, True] 1599.1935629569914
# ['add', False, 'add', 12, False, False] 1610.9064729397026
